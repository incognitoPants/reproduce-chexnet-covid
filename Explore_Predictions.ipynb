# %% [markdown]
# # Reproduce CheXNet (with COVID-19): Explore Predictions

# %% [markdown]
# This notebook was modified to include Covid as a label. The accompanying `visualize_prediction.py` file was also updated.
# All other aspects of the notebook from [reproduce-chexnet](https://github.com/jrzech/reproduce-chexnet) remain the same.

# %% [markdown]
# ## Import other modules and pandas

# %%
import visualize_prediction as V

import pandas as pd

#suppress pytorch warnings about source code changes
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Settings for review
# We can examine individual results in more detail, seeing probabilities of disease for test images.
#
# We get you started with a small number of the images from the large NIH dataset and the aggregated Kaggle COVID-19 Radiography dataset.
#
# To explore the full dataset, [download images from NIH (large, ~40gb compressed)](https://nihcc.app.box.com/v/ChestXray-NIHCC) and [Kaggle (COVID folder only)](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database). Extract all tar.gz and zip files to a single folder, place that path below and set STARTER_IMAGES=False

# %%
STARTER_IMAGES=True
PATH_TO_IMAGES = "starter_images/"

#STARTER_IMAGES=False
#PATH_TO_IMAGES = "images"

# %% [markdown]
# Load pretrained model (part of cloned repo; should not need to change path unless you want to point to one you retrained)

# %%
PATH_TO_MODEL = "pretrained/checkpoint"
# Use the path below if you want to use your retrained model instead
#PATH_TO_MODEL = "results/checkpoint"

# %% [markdown]
# Pick the finding you want to see positive examples of:
#
# LABEL can be set to any of:
# - Atelectasis
# - Cardiomegaly
# - Consolidation
# - Covid
# - Edema
# - Effusion
# - Emphysema
# - Fibrosis
# - Hernia
# - Infiltration
# - Mass
# - Nodule
# - Pleural_Thickening
# - Pneumonia
# - Pneumothorax

# %%
#LABEL="Pneumonia"
LABEL="Covid"

# %% [markdown]
# It's more interesting when initially exploring to see cases positive for pathology of interest:

# %%
POSITIVE_FINDINGS_ONLY=True

# %% [markdown]
# ## Load data
#
# This loads up dataloader and model (note: only test images not used for model training are loaded).

# %%
dataloader,model= V.load_data(PATH_TO_IMAGES,LABEL,PATH_TO_MODEL,POSITIVE_FINDINGS_ONLY,STARTER_IMAGES)
print("Cases for review:")
print(len(dataloader))
# Out:
# Cases for review:
# 10

# %% [markdown]
# ## Examine individual cases
#
# To explore, run code below to see a random case positive for your selected finding, a heatmap indicating the most influential regions of the image, and the model's estimated probabilities for findings. For many diagnoses, you can see that the model uses features outside the expected region to calibrate its predictions -- [you can read John Zech's discussion about this here](https://medium.com/@jrzech/what-are-radiological-deep-learning-models-actually-learning-f97a546c5b98).
#
# You can run the below cell repeatedly to see different examples:

# %%
preds= V.show_next(dataloader,model, LABEL)
preds
# Out:
#                    Predicted Probability  Ground Truth
# Finding
# Covid                              0.999          True
# Infiltration                       0.005         False
# Effusion                           0.002         False
# Nodule                             0.002         False
# Atelectasis                        0.001         False
# Mass                               0.001         False
# Pneumothorax                       0.001         False
# Pleural_Thickening                 0.001         False
# Cardiomegaly                       0.000         False
# Pneumonia                          0.000         False
# Consolidation                      0.000         False
# Edema                              0.000         False
# Emphysema                          0.000         False
# Fibrosis                           0.000         False
# Hernia                             0.000         False
